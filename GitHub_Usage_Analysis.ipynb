# %%
# !pip install numpy pandas matlplotlib
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement matlplotlib (from versions: none)
# ERROR: No matching distribution found for matlplotlib

# %%
df = pd.read_csv('SakshiKhare7-github-usuage-report.csv')
df
# Out:
#            Date             Product               SKU  Quantity Unit Type  \
# 0    2023-12-05      Shared Storage    Shared Storage    0.0000    gb-day
# 1    2023-12-06      Shared Storage    Shared Storage    0.0000    gb-day
# 2    2023-12-07             Actions  Compute - UBUNTU    1.0000    minute
# 3    2023-12-07      Shared Storage    Shared Storage    0.0000    gb-day
# 4    2023-12-08      Shared Storage    Shared Storage    0.0000    gb-day
# ..          ...                 ...               ...       ...       ...
# 199  2024-06-01  Codespaces - Linux           Storage    0.0023  gb-month
# 200  2024-06-01  Codespaces - Linux  Compute - 2 core    0.6324      hour
# 201  2024-06-01  Codespaces - Linux           Storage    0.0417  gb-month
# 202  2024-06-01  Codespaces - Linux           Storage    0.6984  gb-month
# 203  2024-06-02  Codespaces - Linux           Storage    0.2037  gb-month
#
#      Price Per Unit ($)  Multiplier         Owner           Repository Slug  \
# ...

# %%
# # Convert 'Date' column to datetime type
# df['Date'] = pd.to_datetime(df['Date'])

# # Group by date and product, then sum quantities
# grouped_df = df.groupby(['Date', 'Product']).sum().unstack(fill_value=0)

# # Plotting
# fig, ax = plt.subplots(figsize=(10, 6))

# # Bar width
# bar_width = 0.35

# # Indices for plotting
# indices = range(len(grouped_df.index))

# # Plot Shared Storage
# ax.bar(indices, grouped_df['Quantity']['Shared Storage'], bar_width, label='Shared Storage')

# # Plot Actions
# ax.bar([i + bar_width for i in indices], grouped_df['Quantity']['Actions'], bar_width, label='Actions')

# # Adding labels and title
# ax.set_xlabel('Date')
# ax.set_ylabel('Quantity')
# ax.set_title('Usage of Shared Storage and Actions')
# ax.set_xticks([i + bar_width / 2 for i in indices])
# ax.set_xticklabels(grouped_df.index.strftime('%Y-%m-%d'))
# ax.legend()

# # Rotate date labels for better readability
# plt.xticks(rotation=45)

# # Show the plot
# plt.tight_layout()
# plt.show()

# %%
# Group by product and sum the quantities
grouped_df = df.groupby('Product').sum()

# Plotting
fig, ax = plt.subplots(figsize=(8, 8))

# Plot a pie chart
ax.pie(grouped_df['Quantity'], labels=grouped_df.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])

# Adding a title
ax.set_title('Proportion of Shared Storage and Actions Usage')

# Equal aspect ratio ensures the pie chart is circular
ax.axis('equal')

# Show the plot
plt.show()

# %%
df.head()
# Out:
#          Date         Product               SKU  Quantity Unit Type  \
# 0  2023-12-05  Shared Storage    Shared Storage       0.0    gb-day
# 1  2023-12-06  Shared Storage    Shared Storage       0.0    gb-day
# 2  2023-12-07         Actions  Compute - UBUNTU       1.0    minute
# 3  2023-12-07  Shared Storage    Shared Storage       0.0    gb-day
# 4  2023-12-08  Shared Storage    Shared Storage       0.0    gb-day
#
#    Price Per Unit ($)  Multiplier         Owner    Repository Slug  \
# 0               0.008         1.0  SakshiKhare7   API-Benchmarking
# 1               0.008         1.0  SakshiKhare7   API-Benchmarking
# 2               0.008         1.0  SakshiKhare7  open-sauced-goals
# 3               0.008         1.0  SakshiKhare7   API-Benchmarking
# 4               0.008         1.0  SakshiKhare7   API-Benchmarking
#
#        Username                     Actions Workflow  Notes
# 0           NaN                                  NaN    NaN
# ...

# %%
plt.ylabel("Price Per Unit ($)")
plt.xlabel("Date")
plt.title("Price Per Unit ($) VS Date" )
plt.bar(df['Date'],df['Price Per Unit ($)'])
plt.show()

# %%
plt.ylabel("Quantity")
plt.xlabel("Product")
plt.title("Average Quantity VS Product" )
#plt.bar(df['Date'],df['Price Per Unit ($)'])
df.groupby('Product')['Quantity'].mean().plot(kind = 'pie')
#plt.pie(df['Quantity'],df('Product'))
plt.show()

# %%
plt.ylabel("Price Per Unit ($)")
plt.xlabel("Product")
plt.title('Price Per Unit ($) VS Product')
df.groupby('Product')['Price Per Unit ($)'].sum().plot(kind ='area')
plt.show()

# %%
plt.ylabel("Product")
plt.xlabel("Quantity")
plt.title('Quantity VS Product')
plt.bar(df['Product'],df['Quantity'])
# Out:
# <BarContainer object of 204 artists>
